# %%
import pandas as pd

# Charger les deux fichiers
recipes = pd.read_csv('../data/raw/recipe.csv')
user_recipe = pd.read_csv('../data/raw/user_recipe.csv')

# Explorer recipe.csv
print("=== RECIPES ===")
print("Shape:", recipes.shape)
print("\nColonnes:", recipes.columns.tolist())
print("\nPremières lignes:")
print(recipes.head(3))

# Explorer user_recipe.csv
print("\n=== USER_RECIPE ===")
print("Shape:", user_recipe.shape)
print("\nColonnes:", user_recipe.columns.tolist())
print("\nPremières lignes:")
print(user_recipe.head(3))
